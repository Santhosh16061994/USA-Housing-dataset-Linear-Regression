# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data2 = pd.read_csv('/content/drive/MyDrive/Nisarg ML Notes/USA_Housing.csv')

# %%
data2.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data2.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
data2.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data2.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
data2.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data2.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
columns = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']

# %%
# Create a pair plot with customizations
sns.set(style='ticks', color_codes=True)
sns.pairplot(data2[columns], diag_kind='kde', plot_kws={'alpha': 0.5})

# Customizing the pair plot layout
plt.subplots_adjust(top=0.95)
plt.suptitle('Pair Plot', fontsize=16)


# Display the pair plot
plt.show()

plt.savefig('plot.png')

# %%
data2.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
# Create a histogram plot
plt.hist(data2['Avg. Area Income'], bins=30, edgecolor='black')

# Add labels and title
plt.xlabel('Avg. Area Income')
plt.ylabel('Frequency')
plt.title('Histogram Plot')

plt.savefig('plot.png')

# %%
data2.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
data2.shape
# Out:
# (5000, 7)

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 4))

axs[0].hist(data2['Avg. Area Income'], bins=30, edgecolor='black')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Avg. Area Income')
axs[0].set_title('Histogram 1')

axs[1].hist(data2['Avg. Area House Age'], bins=30, edgecolor='black')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Avg. Area House Age')
axs[1].set_title('Histogram 2')

axs[2].hist(data2['Avg. Area Number of Rooms'], bins=30, edgecolor='black')
axs[2].set_xlabel('Value')
axs[2].set_ylabel('Avg. Area Number of Rooms')
axs[2].set_title('Histogram 3')
# Out:
# Text(0.5, 1.0, 'Histogram 3')

# %%
data2.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.scatterplot(x=data2['Avg. Area House Age'], y=data2['Price'])
# Out:
# <Axes: xlabel='Avg. Area House Age', ylabel='Price'>

# %%
sns.scatterplot(x=data2['Avg. Area Income'], y=data2['Area Population'], hue=data2['Price'])
# Out:
# <Axes: xlabel='Avg. Area Income', ylabel='Area Population'>

# %%
# Calculate the correlation coefficient
correlation_coefficient = data2['Avg. Area Income'].corr(data2['Avg. Area House Age'])

# %%
# Calculate the correlation coefficient
correlation_coefficient = data2['Avg. Area Income'].corr(data2['Price'])

# %%
# Print the correlation coefficient
print('Correlation Coefficient:', correlation_coefficient)
# Out:
# Correlation Coefficient: 0.6397337782498941

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


# Compute the correlation matrix
correlation_matrix = data2.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Set plot title
plt.title('Correlation Matrix')

# Display the correlation matrix heatmap
plt.show()

plt.savefig('Heatmap.png')

from google.colab import files
files.download('Heatmap.png')
# Out:
# <ipython-input-23-d8d8c4a468b9>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data2.corr()

# %%
# Create a box plot
plt.figure(figsize=(20, 10))
sns.boxplot(data=data2)

# Set plot title
plt.title('Box Plot')

# Display the box plot
plt.show()

# %%
def detect_outliers_iqr(data):
    outlier_list = []
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    #print("The Val of Q1 and Q2",q1, q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    #print("The lower & Upper Bound",lwr_bound, upr_bound)
    
    for i in data: 
        if (i<lwr_bound or i>upr_bound):
            outlier_list.append(i)
    return outlier_list 



for i in ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price',]:
    outliers = detect_outliers_iqr(data2[i])
    print("Outliers in",i,"attribute :", outliers)
# Out:
# Outliers in Avg. Area Income attribute : [17796.631189543397, 35454.714659475445, 35608.986237077515, 35797.323121548245, 35963.330809062856, 36100.444226680745, 37908.67586272925, 37971.20756623529, 38122.524488262905, 38139.919044520015, 38530.12447825256, 38571.963669753466, 38734.005216471945, 38868.25031141422, 39033.809236982364, 39294.036523316114, 39411.652787814426, 39653.77003073781, 39777.606906208486, 97548.31041260507, 97669.06449084358, 97881.58727937556, 98468.2536411164, 99317.82314540035, 99629.01358134775, 100741.29858525375, 101144.3239296864, 101599.6705804352, 101928.85805987818, 102881.12090226932, 104702.7242570266, 107701.74837763936]
# ...

# %%
# Handling outliers using Quantile based flooring and capping method.
#the outlier is capped at a certain value above the 90th percentile value or floored at a factor below the 10th percentile value
# Computing 10th, 90th percentiles and replacing the outliers

def handle_outliers(data):

    tenth_percentile = np.percentile(data, 10)
    ninetieth_percentile = np.percentile(data, 90)
    
    b = np.where(data<tenth_percentile, tenth_percentile, data)

    b1 = np.where(b>ninetieth_percentile, ninetieth_percentile, b)
    return b1
    
    
for i in ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price',]:
           data2[i]=handle_outliers(data2[i])
           print(data2[i])
# Out:
# 0       79545.458574
# 1       79248.642455
# 2       61287.067179
# 3       63345.240046
# 4       59982.197226
#             ...
# 4995    60567.944140
# 4996    78491.275435
# 4997    63390.686886
# 4998    68001.331235
# 4999    65510.581804
# Name: Avg. Area Income, Length: 5000, dtype: float64
# 0       5.682861
# 1       6.002900
# 2       5.865890
# 3       7.188236
# 4       5.040555
#           ...
# 4995    7.243978
# 4996    6.999135
# 4997    7.243978
# 4998    5.534388
# 4999    5.992305
# Name: Avg. Area House Age, Length: 5000, dtype: float64
# 0       7.009188
# 1       6.730821
# 2       8.274222
# 3       5.681951
# 4       7.839388
#           ...
# 4995    6.137356
# 4996    6.576763
# 4997    5.681951
# 4998    7.130144
# 4999    6.792336
# Name: Avg. Area Number of Rooms, Length: 5000, dtype: float64
# 0       4.09
# 1       3.09
# 2       5.13
# 3       3.26
# 4       4.23
#         ...
# 4995    3.46
# 4996    4.02
# 4997    2.31
# 4998    5.44
# ...

# %%
# Create a box plot
plt.figure(figsize=(20, 10))
sns.boxplot(data=data2)

# Set plot title
plt.title('Box Plot')

# Display the box plot
plt.show()

# %%
data2.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
data2.to_csv('output.csv', index=False)

# %%
# feature_cols = ['Avg. Area Income']
# x = data2[feature_cols] # Features
# y = data2.Price # Target variable

# %%
X = data2.drop(['Price', 'Address'], axis=1)
y = data2['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

# %%
def print_evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE', mae)
    print('MSE', mse)
    print('RMSE', rmse)
    print('R2 square', r2_square)
    print('------------------------------------------')

# %%
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3500, 5)
# (1500, 5)
# (3500,)
# (1500,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# 1228345.983012552

# %%
print(model.coef_)
# Out:
# [185523.79498472 129297.20688196  95436.74163201    962.8351479
#  116250.05413615]

# %%
coeff_df = pd.DataFrame(model.coef_, X.columns, columns = ['Coefficient'])
coeff_df
# Out:
#                                 Coefficient
# Avg. Area Income              185523.794985
# Avg. Area House Age           129297.206882
# Avg. Area Number of Rooms      95436.741632
# Avg. Area Number of Bedrooms     962.835148
# Area Population               116250.054136

# %%
pred = model.predict(X_test)

# %%
sns.scatterplot(x=y_test, y=pred)
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
model.coef_[0]
# Out:
# 185523.79498471937

# %%
model.intercept_
# Out:
# 1228345.983012552

# %%
Pred1 = model.predict(X_test)

# %%
Pred1
# Out:
# array([1299293.58055812, 1228848.35580827, 1247527.61644022, ...,
#        1441224.67742849, 1237332.76757822, 1057386.05464661])

# %%
y_test
# Out:
# 1501    1.339096e+06
# 2586    1.251794e+06
# 2653    1.340095e+06
# 1055    1.431508e+06
# 705     1.042374e+06
#             ...
# 3563    1.348222e+06
# 1538    1.309937e+06
# 1837    1.472887e+06
# 2380    1.409762e+06
# 1912    1.009606e+06
# Name: Price, Length: 1500, dtype: float64

# %%
# my_multiple_linear_preds_train = model.predict(X_train)
# print('MAE on Train Data :', mean_absolute_error(my_multiple_linear_preds_train,y_train))
# print('MSE on Train Data :', mean_squared_error(my_multiple_linear_preds_train,y_train))
# print('RMSE on Train Data :', np.sqrt(mean_squared_error(my_multiple_linear_preds_train,y_train)))
# print('R-squared on Train Data :', model.score(X_train, y_train))

# %%
test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

# %%
print("Test Set Evaluation:\n___________________")
print_evaluate(y_test, test_pred)

print("Train Set Evaluation:\n_____________________")
print_evaluate(y_train, train_pred)
# Out:
# Test Set Evaluation:
# ___________________
# MAE 92167.35901999175
# MSE 13277382917.62204
# RMSE 115227.52673568083
# R2 square 0.8379931910048378
# ------------------------------------------
# Train Set Evaluation:
# _____________________
# MAE 93038.58262630325
# MSE 13798200840.064514
# RMSE 117465.74326187407
# R2 square 0.841591028602996
# ------------------------------------------

# %%
from sklearn.linear_model import Ridge

my_ridge_model = Ridge(100000).fit(X_train, y_train)

my_preds_train = my_ridge_model.predict(X_train)
my_preds_test = my_ridge_model.predict(X_test)

print("Test Set Evaluation:\n___________________")
print_evaluate(y_test, test_pred)

print("Train Set Evaluation:\n_____________________")
print_evaluate(y_train, train_pred)
# Out:
# Test Set Evaluation:
# ___________________
# MAE 92167.35901999175
# MSE 13277382917.62204
# RMSE 115227.52673568083
# R2 square 0.8379931910048378
# ------------------------------------------
# Train Set Evaluation:
# _____________________
# MAE 93038.58262630325
# MSE 13798200840.064514
# RMSE 117465.74326187407
# R2 square 0.841591028602996
# ------------------------------------------

# %%
from sklearn.linear_model import Lasso

# %%
# we want that the value of R squre should be move towards 1 
# and train and test data value should be nearest.
my_lasso = Lasso(100000).fit(X_train, y_train)

my_preds_train = my_lasso.predict(X_train)
my_preds_test = my_lasso.predict(X_test)
print("Test Set Evaluation:\n___________________")
print_evaluate(y_test, test_pred)

print("Train Set Evaluation:\n_____________________")
print_evaluate(y_train, train_pred)
# Out:
# Test Set Evaluation:
# ___________________
# MAE 92167.35901999175
# MSE 13277382917.62204
# RMSE 115227.52673568083
# R2 square 0.8379931910048378
# ------------------------------------------
# Train Set Evaluation:
# _____________________
# MAE 93038.58262630325
# MSE 13798200840.064514
# RMSE 117465.74326187407
# R2 square 0.841591028602996
# ------------------------------------------

# %%
from sklearn.linear_model import ElasticNet

my_ElasticNet = ElasticNet(alpha=0.01).fit(X_train, y_train)

my_preds_train = my_ElasticNet.predict(X_train)
my_preds_test = my_ElasticNet.predict(X_test)

print("Test Set Evaluation:\n___________________")
print_evaluate(y_test, test_pred)

print("Train Set Evaluation:\n_____________________")
print_evaluate(y_train, train_pred)
# Out:
# Test Set Evaluation:
# ___________________
# MAE 92167.35901999175
# MSE 13277382917.62204
# RMSE 115227.52673568083
# R2 square 0.8379931910048378
# ------------------------------------------
# Train Set Evaluation:
# _____________________
# MAE 93038.58262630325
# MSE 13798200840.064514
# RMSE 117465.74326187407
# R2 square 0.841591028602996
# ------------------------------------------

# %%
from sklearn.model_selection import GridSearchCV

# grid search to helps us to find the alpha value

# %%
params = {'alpha':[0.001, 0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10], 'max_iter':[1500, 10000, 100000]}
grid_search = GridSearchCV(my_ElasticNet, params)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=ElasticNet(alpha=0.01),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10],
#                          'max_iter': [1500, 10000, 100000]})

# %%
grid_search.best_params_

# it will give best combinations.
# Out:
# {'alpha': 0.001, 'max_iter': 1500}

# %%
my_preds_train = grid_search.predict(X_train)
my_preds_test = grid_search.predict(X_test)

# %%
print("Test Set Evaluation:\n___________________")
print_evaluate(y_test, test_pred)

print("Train Set Evaluation:\n_____________________")
print_evaluate(y_train, train_pred)
# Out:
# Test Set Evaluation:
# ___________________
# MAE 92167.35901999175
# MSE 13277382917.62204
# RMSE 115227.52673568083
# R2 square 0.8379931910048378
# ------------------------------------------
# Train Set Evaluation:
# _____________________
# MAE 93038.58262630325
# MSE 13798200840.064514
# RMSE 117465.74326187407
# R2 square 0.841591028602996
# ------------------------------------------

# %%
results_df = pd.DataFrame(data=[['Linear regression', *evaluate(y_test, test_pred), cross_val(LinearRegression())]],
                         columns = ['Model', 'MAE', 'MSE','RMSE', 'R2 Square', 'Cross Validation'])

# %%
results_df
# Out:
#                Model          MAE           MSE           RMSE  R2 Square  \
# 0  Linear regression  92167.35902  1.327738e+10  115227.526736   0.837993
#
#    Cross Validation
# 0          0.839735
